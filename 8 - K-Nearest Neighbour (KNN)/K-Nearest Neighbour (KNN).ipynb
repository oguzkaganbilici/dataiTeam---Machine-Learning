# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Import Data

# %%
dt = pd.read_csv("data.csv")
dt.head()
# M -> kotu huylu
# B -> iyi huylu tümor
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
dt.drop(["id","Unnamed: 32"], axis=1, inplace=True)
dt.head()
# Out:
#   diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0         M        17.99         10.38          122.80     1001.0
# 1         M        20.57         17.77          132.90     1326.0
# 2         M        19.69         21.25          130.00     1203.0
# 3         M        11.42         20.38           77.58      386.1
# 4         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    symmetry_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# ...

# %% [markdown]
# ## Basic Visualization

# %%
M = dt[dt.diagnosis == "M"]
B = dt[dt.diagnosis == "B"]

# %%
plt.scatter(M.radius_mean, M.texture_mean, color="red", label="Bad", alpha=0.3) # alpha saydamlık verir.
plt.scatter(B.radius_mean, B.texture_mean, color="blue", label="Good", alpha=0.3)
plt.legend()
plt.xlabel("Radius mean")
plt.ylabel("Texture mean")
plt.show()

# %% [markdown]
# ## KNN
#
# 1) determine a K value (bir noktaya k tane nokta buluruz)
# 2) find the nearest K points
# 3) calculate how many classes are there
# 4) determine class of the point or data

# %%
dt.diagnosis = [1 if each == "M" else 0 for each in dt.diagnosis]
y = dt.diagnosis.values
x_data = dt.drop(["diagnosis"], axis=1)

# %% [markdown]
# ### Normalization

# %%
x = (x_data - np.min(x_data)) / (np.max(x_data) - np.min(x_data))
x.head()
# Out:
#    radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  \
# 0     0.004229      0.002440        0.028867   0.235308         0.000028
# 1     0.004835      0.004177        0.031241   0.311707         0.000020
# 2     0.004629      0.004995        0.030559   0.282793         0.000026
# 3     0.002685      0.004791        0.018237   0.090762         0.000033
# 4     0.004770      0.003371        0.031758   0.304890         0.000024
#
#    compactness_mean  concavity_mean  concave points_mean  symmetry_mean  \
# 0          0.000065        0.000071             0.000035       0.000057
# 1          0.000018        0.000020             0.000016       0.000043
# 2          0.000038        0.000046             0.000030       0.000049
# 3          0.000067        0.000057             0.000025       0.000061
# 4          0.000031        0.000047             0.000025       0.000043
#
#    fractal_dimension_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# ...

# %% [markdown]
# ### Train - Test split

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=42)

# %% [markdown]
# ### KNN

# %%
from sklearn.neighbors import KNeighborsClassifier

knn = KNeighborsClassifier(n_neighbors=3) # n_neighbors = k
knn.fit(x_train,y_train)
# Out:
# KNeighborsClassifier(n_neighbors=3)

# %% [markdown]
# ### prediction

# %%
y_head = knn.predict(x_test.values)
# Out:
# C:\Users\oguzk\anaconda3\envs\py3-TF2.0\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but KNeighborsClassifier was fitted with feature names
#   warnings.warn(

# %% [markdown]
# ### Score

# %%
print("{}-nn score: {}".format(3, knn.score(x_test.values, y_test)))
# Out:
# 3-nn score: 0.9415204678362573
# C:\Users\oguzk\anaconda3\envs\py3-TF2.0\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but KNeighborsClassifier was fitted with feature names
#   warnings.warn(

# %% [markdown]
# ### Find the best K value

# %%
score_list = []
for i in range(1,15):
    knn2 = KNeighborsClassifier(n_neighbors=i)
    knn2.fit(x_train, y_train)
    score_list.append(knn2.score(x_test.values, y_test))
    
    
plt.plot(range(1,15), score_list)
plt.xlabel("K value")
plt.ylabel("accuracy")
plt.show()
# Out:
# C:\Users\oguzk\anaconda3\envs\py3-TF2.0\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but KNeighborsClassifier was fitted with feature names
#   warnings.warn(
# C:\Users\oguzk\anaconda3\envs\py3-TF2.0\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but KNeighborsClassifier was fitted with feature names
#   warnings.warn(
# C:\Users\oguzk\anaconda3\envs\py3-TF2.0\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but KNeighborsClassifier was fitted with feature names
#   warnings.warn(
# C:\Users\oguzk\anaconda3\envs\py3-TF2.0\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but KNeighborsClassifier was fitted with feature names
#   warnings.warn(
# ...
